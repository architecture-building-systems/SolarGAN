# %%
import sys
import numpy as np
np.set_printoptions(threshold=sys.maxsize)

# %%
zurich = np.load("zurich_gen_feat_test.npy")
print(zurich.shape)

zurich_gt = np.load("zurich_gt_feat_test.npy")
print(zurich_gt.shape)
# Out:
# (100, 8736, 20)
# (100, 8736, 1)

# %%
print(zurich[0,:,0])
# Out:
# [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  1.29857345e-03 1.49160463e-04 1.14063878e-04 6.81751082e-03
#  3.36836791e+00 1.42911253e+01 2.42771549e+01 1.63727989e+01
#  1.37436543e+01 1.76239228e+00 2.24160981e+00 1.20429528e+00
#  1.00051574e-01 2.63224338e-05 8.77414459e-06 1.75482892e-05
#  8.77414423e-05 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  8.19241926e-02 2.98320927e-04 0.00000000e+00 2.10579461e-03
#  1.90243282e+01 2.78650093e+01 1.01621147e+02 1.86802231e+02
#  2.66110565e+02 2.50339462e+02 2.10370056e+02 2.59100838e+01
#  1.97444573e-01 3.33417498e-04 1.75482892e-05 4.38707211e-05
#  1.22487061e-02 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  2.28127767e-03 8.77414423e-05 1.22838028e-04 7.58173838e-02
#  3.97660217e+01 1.65958557e+02 2.26892197e+02 5.74111595e+01
# ...

# %%
zurich_mean = np.mean(zurich, 2)
print(zurich_mean.shape)
print(zurich_mean[0,:])
# Out:
# (100, 8736)
# [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  2.73111811e-03 1.33931027e-03 2.24508481e-04 5.21333927e-03
#  1.67799422e+00 6.29459139e+00 2.77936950e+01 8.14519903e+01
#  1.16763724e+02 9.41015941e+01 8.99080786e+01 8.80923221e+00
#  4.20410870e-01 3.00092412e-04 6.23758206e-06 1.75482892e-06
#  8.43122896e-05 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  2.94211130e-02 5.22512203e-03 4.37235994e-05 2.11329016e-02
#  6.57006210e+00 1.22099591e+01 3.36085111e+01 5.26076543e+01
#  1.14021824e+02 1.30115655e+02 9.77187660e+01 1.18456151e+01
#  1.59410600e-01 8.13945882e-04 1.03894200e-04 2.78549343e-05
#  8.93200651e-03 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  1.16454413e-03 6.14503776e-04 2.94202873e-05 1.43310705e-02
#  8.42246269e+00 5.84379303e+01 8.08704608e+01 2.89327518e+01
# ...

# %%
np.savetxt("zurich_gen.txt", zurich_mean[:,0])

# %%
zurich_mean_mean = np.mean(zurich_mean, 1)
print(zurich_mean_mean.shape)
print(zurich_mean_mean)
np.savetxt("zurich_gen_mean.txt", zurich_mean_mean)
# Out:
# (8736,)
# [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  3.01102865e-01 3.05422661e-01 2.67956377e-01 2.87740645e-01
#  5.10487832e+00 1.71553827e+01 3.16918073e+01 4.13352006e+01
#  4.09906879e+01 2.58083829e+01 2.03615925e+01 8.61837385e+00
#  1.00997787e+00 2.91284900e-01 2.82056961e-01 2.89127317e-01
#  2.77051512e-01 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  2.98671695e-01 2.56974260e-01 2.58396999e-01 3.15578607e-01
#  1.30032646e+01 2.11442017e+01 6.22211975e+01 7.14490083e+01
#  8.81648215e+01 7.20304725e+01 6.63503539e+01 2.40848710e+01
#  9.15878472e-01 3.37385203e-01 3.22562850e-01 3.04076087e-01
#  2.66960339e-01 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  2.58856075e-01 2.64101058e-01 2.77126594e-01 2.96130652e-01
#  1.83611349e+01 6.69077042e+01 8.29084060e+01 4.04866120e+01
# ...

# %%
zurich_gt_mean = np.mean(zurich_gt, 2)
print(zurich_gt_mean.shape)
np.savetxt("zurich_gt_mean.txt", zurich_gt_mean)
# Out:
# (100, 8736)
